# %%
# !pip install hmmlearn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split,GridSearchCV
import hmmlearn
from hmmlearn import hmm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Data**

# %%
x = pd.read_csv ('/content/drive/MyDrive/Colab Notebooks/Data Mining/ETS_HiddenMarkov/df_slidingwindow.csv')
x
# Out:
#        Unnamed: 0     id           x1          y1      xVel1     yVel1  \
# 0               0      0   562.050000   -0.620000 -10.700000 -4.330000
# 1               1      1   368.855000  -28.855000  -4.195000 -3.500000
# 2               2      2   200.160000  -57.090000   2.310000 -4.330000
# 3               3      3   258.575000 -188.580000   1.580000 -3.500000
# 4               4      4   316.990000  -57.090000   0.850000 -2.670000
# ...           ...    ...          ...         ...        ...       ...
# 30763       30763  30763  1084.140028 -662.823937  -7.296511 -0.595615
# 30764       30764  30764  1097.738080 -664.774544  -7.831900 -0.861126
# 30765       30765  30765  1097.738080 -662.823937  -7.831900 -0.595615
# 30766       30766  30766  1097.738080 -154.983826  -7.831900  2.167211
# 30767       30767  30767  1097.738080  369.400521  -7.831900  5.283305
#
#             xA1       yA1       xS1       yS1  ...    yVel200     xA200  \
# ...

# %%
X=x.drop(["id","Swarm_Behaviour"],axis=1)
Y=x["Swarm_Behaviour"]

# %% [markdown]
# # **Split Data**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.25,random_state=101)

# %% [markdown]
# # **Hidden Markov Model (Training Data)**

# %%
# Build the HMM model
model = hmm.GaussianHMM(n_components = 3, covariance_type = "diag", n_iter = 50, random_state = 42)
ytrain = model.fit(X_train)

# %%
# Predict the hidden states corresponding to observed X.
ypred = model.predict(X_test)
states = pd.unique(ypred)

# %% [markdown]
# # **Testing Data**

# %%
print(classification_report(Y_test, ypred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.70      0.57      0.63      3838
#          1.0       0.97      0.50      0.66      3854
#          2.0       0.00      0.00      0.00         0
#
#     accuracy                           0.53      7692
#    macro avg       0.56      0.36      0.43      7692
# weighted avg       0.84      0.53      0.64      7692
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
# ...
